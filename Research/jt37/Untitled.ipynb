# %%
import requests

r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '18818096675',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 246411607,
#    'name': 'COVID19Tracking/covid-tracking-data',
#    'url': 'https://api.github.com/repos/COVID19Tracking/covid-tracking-data'},
#   'payload': {'push_id': 8351082141,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '11bdd97ce408952328f9b1a0676ef7af0359fd14',
#    'before': '6a34b3fbb94cb50e51cbf32d100ad18348ef897c',
#    'commits': [{'sha': '11bdd97ce408952328f9b1a0676ef7af0359fd14',
#      'author': {'email': 'actions@github.com', 'name': 'GitHub Actions'},
#      'message': 'Updating HHS data backups',
#      'distinct': True,
# ...
