# %%
import pandas as pd
import requests
import csv
import time

# %%
# List of values that I'll use to get the stop_id, gotten from google_transit info
to_find = ["MTD5430", "MTD7234", "MTD2111", "MTD3513", "MTD7411", 
           "MTD3121", "MTD3171", "MTD1374", "MTD0173", "MTD3263",
           "MTD4262", "MTD2063"]

# %%
# Checking for any duplicates
flag = 0
for i in range(len(to_find)):
    for j in range(len(to_find)):
        if to_find[i] == to_find[j] and i != j:
            flag = 1
flag
# Out:
# 0

# %%
# Dictionary, stops with their respective id, enter path to your file
path = '/Users/Guero/Desktop/universal/classworm/CS196124/extra/google_transit/stops.txt'
yellow_stops = {}
with open(path) as csv_file: 
    csv_reader = csv.reader(csv_file, delimiter = ',')
    line_count = 0
    for row in csv_reader:
        if row[1] in to_find:
            yellow_stops[row[2]] = row[0]
yellow_stops
# Out:
# {'Kirby & State (SW Corner)': 'KBYSTE:3',
#  'Woodfield & Curtis (NW Corner)': 'WDFLDCTS:4',
#  'Fox & Windsor (SE Corner)': 'FOXWDSR:2',
#  'Lot E-14 (South Shelter)': 'E14:1',
#  'Fox & Windsor (NE Corner)': 'FOXWDSR:1',
#  'The Place at 117 (East Side)': 'INDIGO:2',
#  'Gregory at Ikenberry Commons (North)': 'GRGIKE:2',
#  'Champaign Walmart (East Shelter)': 'WALMART:2',
#  'Market Place (NE Mall Entrance)': 'MKTPLC:1',
#  'Kirby & State (NE Corner)': 'KBYSTE:1',
#  'Woodfield & Curtis (NE Far Side)': 'WDFLDCTS:5',
#  'Kirby & State (NW Corner)': 'KBYSTE:4',
#  'Savoy Walmart (Dunlap Avenue)': 'SWALMART:1',
#  'Meijer Dr. at Meijer (South Side)': 'MEIJER:1',
#  'Kirby & State (SE Corner)': 'KBYSTE:2',
#  'Gregory at Ikenberry Commons (South)': 'GRGIKE:3',
#  'Fox & Windsor (NW Corner)': 'FOXWDSR:4',
#  'Lot E-14 (North Shelter)': 'E14:2',
#  'Fox & Windsor (NE Far Side)': 'FOXWDSR:5'}

# %%
# Request test, enter your own apikey
apikey = 'abcda32ab81b438fb628a908c94746bb'
reqtest = requests.get('https://developer.cumtd.com/api/v2.2/json/getdeparturesbystop?key=' + apikey + '&stop_id=PLAZA')
reqtest.json()
# Out:
# {'time': '2021-10-23T15:26:30-05:00',
#  'new_changeset': True,
#  'status': {'code': 200, 'msg': 'ok'},
#  'rqst': {'method': 'GetDeparturesByStop', 'params': {'stop_id': 'PLAZA'}},
#  'departures': [{'stop_id': 'PLAZA:4',
#    'headsign': '220N Illini Limited',
#    'route': {'route_color': '5a1d5a',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'route_long_name': 'Illini Limited Saturday',
#     'route_short_name': '220',
#     'route_text_color': 'ffffff'},
#    'trip': {'trip_id': '[@6.0.14330204@][1][1622384291845]/25__I2___UISA',
#     'trip_headsign': 'Lincoln & Killarney',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'block_id': 'I2   UISA',
#     'direction': 'North',
#     'service_id': 'I2   UISA',
#     'shape_id': '[@6.0.14330204@]6'},
#    'vehicle_id': '2040',
#    'origin': {'stop_id': 'ARC:2'},
#    'destination': {'stop_id': 'LNCLNKLRNY:1'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:26:00-05:00',
#    'expected': '2021-10-23T15:27:03-05:00',
#    'expected_mins': 1,
#    'location': {'lat': 40.1054, 'lon': -88.231083}},
#   {'stop_id': 'PLAZA:3',
#    'headsign': '130S Silver',
#    'route': {'route_color': 'cccccc',
#     'route_id': 'SILVER SATURDAY',
#     'route_long_name': 'Silver Saturday',
#     'route_short_name': '130',
#     'route_text_color': '000000'},
#    'trip': {'trip_id': '[@12.0.44184681@][1250945403296]/273__SV2_UISA',
#     'trip_headsign': 'Vet-Med',
#     'route_id': 'SILVER SATURDAY',
#     'block_id': 'SV2 UISA',
#     'direction': 'South',
#     'service_id': 'SV2 UISA',
#     'shape_id': '130S SILVER WEEKEND 3'},
#    'vehicle_id': '1346',
#    'origin': {'stop_id': 'LSE:8'},
#    'destination': {'stop_id': 'VETMED:1'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:34:00-05:00',
#    'expected': '2021-10-23T15:34:00-05:00',
#    'expected_mins': 7,
#    'location': {'lat': 40.111657, 'lon': -88.208083}},
#   {'stop_id': 'PLAZA:3',
#    'headsign': '220S Illini Limited',
#    'route': {'route_color': '5a1d5a',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'route_long_name': 'Illini Limited Saturday',
#     'route_short_name': '220',
#     'route_text_color': 'ffffff'},
#    'trip': {'trip_id': '[@6.0.14330204@][2][1622384445965]/58__I1__UISA',
#     'trip_headsign': 'Transit Plaza',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'block_id': 'I1  UISA',
#     'direction': 'South',
#     'service_id': 'I1  UISA',
#     'shape_id': 'ILLINI LIMITED WEEKEND 845'},
#    'vehicle_id': '2041',
#    'origin': {'stop_id': 'LNCLNKLRNY:1'},
#    'destination': {'stop_id': 'ARC:2'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:33:00-05:00',
#    'expected': '2021-10-23T15:37:42-05:00',
#    'expected_mins': 11,
#    'location': {'lat': 40.132317, 'lon': -88.21785}},
#   {'stop_id': 'PLAZA:3',
#    'headsign': '100S Yellow',
#    'route': {'route_color': 'fcee1f',
#     'route_id': 'YELLOW SATURDAY',
#     'route_long_name': 'Yellow Saturday',
#     'route_short_name': '100',
#     'route_text_color': '000000'},
#    'trip': {'trip_id': '[@15.0.63192124@][2][1338469240094]/21__Y3SA',
#     'trip_headsign': 'Savoy Walmart',
#     'route_id': 'YELLOW SATURDAY',
#     'block_id': 'Y3SA',
#     'direction': 'South',
#     'service_id': 'Y3SA',
#     'shape_id': '[@14.0.57766396@]100S'},
#    'vehicle_id': '1194',
#    'origin': {'stop_id': 'WALMART:2'},
#    'destination': {'stop_id': 'SWALMART:1'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:45:00-05:00',
#    'expected': '2021-10-23T15:45:00-05:00',
#    'expected_mins': 18,
#    'location': {'lat': 40.138003, 'lon': -88.243583}},
#   {'stop_id': 'PLAZA:4',
#    'headsign': '220N Illini Limited',
#    'route': {'route_color': '5a1d5a',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'route_long_name': 'Illini Limited Saturday',
#     'route_short_name': '220',
#     'route_text_color': 'ffffff'},
#    'trip': {'trip_id': '[@6.0.14330204@][1][1622384291845]/26__I1__UISA',
#     'trip_headsign': 'Lincoln & Killarney',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'block_id': 'I1  UISA',
#     'direction': 'North',
#     'service_id': 'I1  UISA',
#     'shape_id': '[@6.0.14330204@]6'},
#    'vehicle_id': '2041',
#    'origin': {'stop_id': 'ARC:2'},
#    'destination': {'stop_id': 'LNCLNKLRNY:1'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:46:00-05:00',
#    'expected': '2021-10-23T15:50:42-05:00',
#    'expected_mins': 24,
#    'location': {'lat': 40.132317, 'lon': -88.21785}},
#   {'stop_id': 'PLAZA:4',
#    'headsign': '130N Silver',
#    'route': {'route_color': 'cccccc',
#     'route_id': 'SILVER SATURDAY',
#     'route_long_name': 'Silver Saturday',
#     'route_short_name': '130',
#     'route_text_color': '000000'},
#    'trip': {'trip_id': '[@12.0.44184681@][1250945403296]/87__SV2_UISA',
#     'trip_headsign': 'Lincoln Square',
#     'route_id': 'SILVER SATURDAY',
#     'block_id': 'SV2 UISA',
#     'direction': 'North',
#     'service_id': 'SV2 UISA',
#     'shape_id': '130N SILVER WEEKEND 1'},
#    'vehicle_id': '1346',
#    'origin': {'stop_id': 'VETMED:1'},
#    'destination': {'stop_id': 'LSE:8'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:52:00-05:00',
#    'expected': '2021-10-23T15:52:00-05:00',
#    'expected_mins': 25,
#    'location': {'lat': 40.111657, 'lon': -88.208083}},
#   {'stop_id': 'PLAZA:3',
#    'headsign': '220S Illini Limited',
#    'route': {'route_color': '5a1d5a',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'route_long_name': 'Illini Limited Saturday',
#     'route_short_name': '220',
#     'route_text_color': 'ffffff'},
#    'trip': {'trip_id': '[@6.0.14330204@][2][1622384445965]/59__I2___UISA',
#     'trip_headsign': 'Transit Plaza',
#     'route_id': 'ILLINI LIMITED SATURDAY',
#     'block_id': 'I2   UISA',
#     'direction': 'South',
#     'service_id': 'I2   UISA',
#     'shape_id': 'ILLINI LIMITED WEEKEND 845'},
#    'vehicle_id': '2040',
#    'origin': {'stop_id': 'LNCLNKLRNY:1'},
#    'destination': {'stop_id': 'ARC:2'},
#    'is_monitored': True,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:53:00-05:00',
#    'expected': '2021-10-23T15:53:00-05:00',
#    'expected_mins': 26,
#    'location': {'lat': 40.1054, 'lon': -88.231083}},
#   {'stop_id': 'PLAZA:3',
#    'headsign': '130S Silver',
#    'route': {'route_color': 'cccccc',
#     'route_id': 'SILVER SATURDAY',
#     'route_long_name': 'Silver Saturday',
#     'route_short_name': '130',
#     'route_text_color': '000000'},
#    'trip': {'trip_id': '[@12.0.44184681@][1250945403296]/274__SV1_UISA',
#     'trip_headsign': 'Vet-Med',
#     'route_id': 'SILVER SATURDAY',
#     'block_id': 'SV1 UISA',
#     'direction': 'South',
#     'service_id': 'SV1 UISA',
#     'shape_id': '130S SILVER WEEKEND 3'},
#    'vehicle_id': 'null',
#    'origin': {'stop_id': 'LSE:8'},
#    'destination': {'stop_id': 'VETMED:1'},
#    'is_monitored': False,
#    'is_scheduled': True,
#    'is_istop': True,
#    'scheduled': '2021-10-23T15:54:00-05:00',
#    'expected': '2021-10-23T15:54:00-05:00',
#    'expected_mins': 27,
#    'location': {'lat': 0, 'lon': 0}}]}

# %%
# Gathering info from Illini Union ->
